# %% [markdown]
# # Marker Repo - annotation

# %% [markdown]
# In this notebook, clustered h5ad files can be annotated using the marker repo.

# %% [markdown]
# ## Loading packages

# %%
import markerrepo.marker_repo as mr
import markerrepo.wrappers as wrap
import markerrepo.annotation as annot
import scanpy as sc
from sctoolbox.tools import celltype_annotation

# %load_ext autoreload
# %autoreload 2
# Out:
# /mnt/workspace2/jdetlef/.conda/envs/sctoolbox/lib/python3.12/site-packages/louvain/__init__.py:54: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import get_distribution, DistributionNotFound

# %% [markdown]
# ## Settings

# %% [markdown]
# Specify path of the cloned repository, the h5ad file which is going to be annotated as well as the organism and the rank genes column of the 'uns' table if available.

# %%
repo_path = "/mnt/workspace/mkessle/projects/annotate_by_marker_and_features"
h5ad_path = "/mnt/workspace/mkessle/master/refdata/hs.h5ad"
organism = mr.select(key="organism", repo_path=repo_path)
rank_genes_column = None
# Out:
# Directory does not exist. Cloning the whitelist repository...
# ---------------------------------------------------------------------------
# GitCommandError                           Traceback (most recent call last)
# Cell In[2], line 3
#       1 repo_path = "/mnt/workspace/mkessle/projects/annotate_by_marker_and_features"
#       2 h5ad_path = "/mnt/workspace/mkessle/master/refdata/hs.h5ad"
# ----> 3 organism = mr.select(key="organism", repo_path=repo_path)
#       4 rank_genes_column = None
#
# File /mnt/workspace2/jdetlef/.conda/envs/sctoolbox/lib/python3.12/site-packages/markerrepo/marker_repo.py:553, in select(whitelist, key, heading, repo_path)
#     551 if not whitelist:
#     552     if key:
# --> 553         whitelist = read_whitelist(key, repo_path=repo_path)['whitelist']
#     554     elif heading:
#     555         raise Exception(f"No values for '{heading}' available. Please try again using other parameters.")
#
# File /mnt/workspace2/jdetlef/.conda/envs/sctoolbox/lib/python3.12/site-packages/markerrepo/utils.py:141, in read_whitelist(key, marker_list, repo_path)
#     134 def read_whitelist(key, marker_list=False, repo_path="."):
#     135     """
#     136     This function reads in a whitelist and returns it.
#     137     :param key: the key that contains a whitelist
#     138     :return: whitelist: the read in whitelist
#     139     """
# --> 141     get_whitelists(repo_path=repo_path, update=False, silent_skip=True)
#     143     try:
#     144         whitelist = read_in_yaml(
#     145             os.path.join(repo_path, 'FRED_whitelists', 'whitelists', key), marker_list=marker_list)
#
# File /mnt/workspace2/jdetlef/.conda/envs/sctoolbox/lib/python3.12/site-packages/markerrepo/utils.py:45, in get_whitelists(repo_path, update, silent_skip)
#      42 else:
#      43     # Clone the repository if it doesn't exist
#      44     print("Directory does not exist. Cloning the whitelist repository...")
# ---> 45     git.Repo.clone_from('https://github.com/loosolab/FRED_whitelists.git', repo_full_path)
#      46     print("Repository cloned.")
#      48 if not silent_skip:
#
# File /mnt/workspace2/jdetlef/.conda/envs/sctoolbox/lib/python3.12/site-packages/git/repo/base.py:1543, in Repo.clone_from(cls, url, to_path, progress, env, multi_options, allow_unsafe_protocols, allow_unsafe_options, **kwargs)
#    1541 if env is not None:
#    1542     git.update_environment(**env)
# -> 1543 return cls._clone(
#    1544     git,
#    1545     url,
#    1546     to_path,
#    1547     GitCmdObjectDB,
#    1548     progress,
#    1549     multi_options,
#    1550     allow_unsafe_protocols=allow_unsafe_protocols,
#    1551     allow_unsafe_options=allow_unsafe_options,
#    1552     **kwargs,
#    1553 )
#
# File /mnt/workspace2/jdetlef/.conda/envs/sctoolbox/lib/python3.12/site-packages/git/repo/base.py:1414, in Repo._clone(cls, git, url, path, odb_default_type, progress, multi_options, allow_unsafe_protocols, allow_unsafe_options, **kwargs)
#    1411     cmdline = remove_password_if_present(cmdline)
#    1413     _logger.debug("Cmd(%s)'s unused stdout: %s", cmdline, stdout)
# -> 1414     finalize_process(proc, stderr=stderr)
#    1416 # Our git command could have a different working dir than our actual
#    1417 # environment, hence we prepend its working dir if required.
#    1418 if not osp.isabs(path):
#
# File /mnt/workspace2/jdetlef/.conda/envs/sctoolbox/lib/python3.12/site-packages/git/util.py:512, in finalize_process(proc, **kwargs)
#     509 """Wait for the process (clone, fetch, pull or push) and handle its errors
#     510 accordingly."""
#     511 # TODO: No close proc-streams??
# --> 512 proc.wait(**kwargs)
#
# File /mnt/workspace2/jdetlef/.conda/envs/sctoolbox/lib/python3.12/site-packages/git/cmd.py:419, in _AutoInterrupt.wait(self, stderr)
#     417     errstr = read_all_from_possibly_closed_stream(p_stderr)
#     418     _logger.debug("AutoInterrupt wait stderr: %r" % (errstr,))
# --> 419     raise GitCommandError(remove_password_if_present(self.args), status, errstr)
#     420 return status
#
# GitCommandError: Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://github.com/loosolab/FRED_whitelists.git /mnt/workspace/mkessle/projects/annotate_by_marker_and_features/FRED_whitelists
#   stderr: 'fatal: could not create leading directories of '/mnt/workspace/mkessle/projects/annotate_by_marker_and_features/FRED_whitelists': Permission denied
# '

# %% [markdown]
# Load anndata

# %%
adata = sc.read_h5ad(h5ad_path)

# %%
adata.var

# %%
adata.obs

# %% [markdown]
# Select which cell type annotation methods you want to perform.

# %%
marker_repo = True
SCSA = True

# %% [markdown]
# The following cell is for specifying the prefixes of new columns in the 'obs' table that will contain the annotation results. Currently, Marker Repo and SCSA are available.

# %%
mr_obs= "MR"
scsa_obs = "SCSA"

# %% [markdown]
# If you want to compare the annotation with a reference annotation already present in the 'obs' table, select the corresponding column.

# %%
reference_obs = mr.select(whitelist=list(adata.obs.columns), heading="reference column")

# %% [markdown]
# ## Prepare adata

# %% [markdown]
# ### Set genes to index, if not already done.

# %% [markdown]
# Pick the genes column.

# %%
genes_column = mr.select(whitelist=list(adata.var.columns), heading="genes column")

# %%
adata.var.reset_index(inplace=True)  # remove peaks from index and save them in the column ['index']
adata.var.set_index(genes_column, inplace=True)  # set genes as index
adata.var.index = adata.var.index.astype('str')  # to avoid index being categorical
adata.var_names_make_unique(join='_')

# %%
adata.var

# %% [markdown]
# ## Prepare annotation

# %% [markdown]
# Pick the clustring column you want to annotate.

# %%
column = mr.select(whitelist=list(adata.obs.columns), heading="clustering column")

# %% [markdown]
# ### Ranking

# %% [markdown]
# Pick the rank genes column, if the anndata object already contains one.

# %%
rank_genes_column = mr.select(whitelist=list(adata.uns.keys()), heading="rank genes column")

# %% [markdown]
# Rank genes, if not already done.

# %%
rank_genes_column = None

# %%
if not rank_genes_column:
    # adata.uns['log1p']['base'] = None
    rank_genes_column = f'rank_genes_groups_{column}'
    print(f'Ranking genes groups for clusters using obs column {column}')
    sc.tl.rank_genes_groups(adata, groupby=f'{column}', use_raw=False, key_added=rank_genes_column)

# %%
sc.pl.rank_genes_groups_matrixplot(adata, standard_scale='var', n_genes=10, key=rank_genes_column, show=True)

# %% [markdown]
# ## Create suitable marker list(s)

# %% [markdown]
# The paths of the marker lists will be stored in the <b>marker_lists</b> variable. They will work as input for the actual cell type annotation of the next cell. If the index of adata.var contains ensembl IDs, set <b>ensembl=True</b>, otherwise gene symbols are used.

# %%
marker_lists = wrap.create_marker_lists(organism, repo_path=repo_path, style="score", file_name=f"{organism.split(' ')[0]}", ensembl=False)

# %%
marker_lists

# %% [markdown]
# ## Annotate adata using the created list(s)

# %%
if marker_repo or SCSA:
    for marker_list in marker_lists:
        columns_to_plot = [] if reference_obs is None else [reference_obs]
        
        name = f"{marker_list.split('/')[-1]}"
        annotation_dir = f"./annotation/{name}"

        if marker_repo:
            ct_column = f"{mr_obs}_{name}"
            columns_to_plot.append(ct_column)
            
            # Run Marker Repo annotation
            annot.annot_ct(adata, output_path=annotation_dir, db_path=marker_list,
                           cluster_column=f"{column}", rank_genes_column=rank_genes_column, 
                           ct_column=ct_column)

            # Show scores and alternate cell types of eacht cluster
            print(f"Tables of cell type annotation with clustering {column}")
            annot.show_tables(annotation_dir=annotation_dir, n=5, clustering_column=column, show_diff=True)

        if SCSA:
            column_added = f"{scsa_obs}_{name}"
            columns_to_plot.append(column_added)
            
            # Run SCSA annotation
            celltype_annotation.run_scsa(adata, 
                 gene_column=None, 
                 key=rank_genes_column, 
                 column_added=column_added,
                 inplace=True, 
                 species=None, 
                 fc=1.5, 
                 pvalue=0.05, 
                 user_db=annot.reformat_marker_list(marker_list), 
                 celltype_column="cell_name")

        # Plot annotation
        sc.pl.umap(adata, color=columns_to_plot, wspace=0.5)

# %% [markdown]
# ### Compare the different annotations

# %%
annot.compare_cell_types(adata, column, columns_to_plot)
