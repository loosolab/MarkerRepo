# %% [markdown]
# # Marker Repo - scoring

# %% [markdown]
# In this notebook, individual markers can be weighted using various functions. In addition, BioMart or the HomoloGene DB enable genes to be transferred from a source organism to a target organism. Thus, even analyses with specific organisms can be performed without already existing suitable lists.

# %% [markdown]
# ## Loading packages

# %%
import markerrepo.marker_repo as mr
import markerrepo.scoring as score
import markerrepo.utils as utils
import markerrepo.wrappers as wrap
import markerrepo.plotting as plot

# %load_ext autoreload
# %autoreload 2
# Out:
# /mnt/workspace2/jdetlef/.conda/envs/marker-repo/lib/python3.14/site-packages/markerrepo/wrappers.py:23: RuntimeWarning: Please install the latest sctoolbox version. Some functionality may not be available.
#   warnings.warn("Please install the latest sctoolbox version. Some functionality may not be available.", RuntimeWarning)

# %% [markdown]
# ## Settings

# %% [markdown]
# Specify path of the cloned repository.

# %%
repo_path = "/mnt/workspace2/jdetlef/repos/annotate_by_marker_and_features"

# %% [markdown]
# # Calculate scores

# %% [markdown]
# This part compares and scores markers from selected marker lists using <b>ubiquitousness index</b>.
# A score of '0' signifies that the marker is the most specific within this selection,
# while a score of '1' indicates that the marker is the most prevalent.

# %% [markdown]
# Start by selecting lists you want to compare.

# %%
results = mr.guided_search(repo_path=repo_path, out="marker_list")
# Out:
# Available columns for search:
# 1: ID
# 2: List name
# 3: Organism name
# 4: Taxonomy ID
# 5: Marker type
# 6: Submitter name
# 7: Source
# 8: List type
# 9: tags_transferred
# 10: Email
# n: Next page
# Enter identifier of column to search in (leave blank to search in all columns):
# Enter search terms (separated by commas, '-' for negative search):
# Number of results: 306
# Do you want to see the results? (yes/no): yes
#                   index                                          List name  \
# ID
# 1688745545837         0                                    HCM_human_fetus
# 17083323392210        1                                 human_gender_genes
# 17103172789694        2                                   stomach_SM-CHLWL
# 168874554211252       3                                 Panglao_human_skin
# 168874554264756       4                                Panglao_human_lungs
# ...                 ...                                                ...
# 1741686472783908    301  zebrafish_cranial_neural_crest_spatial_domain_...
# 1741686677329305    302               zebrafish_cranial_neural_crest_14dpf
# 1741687334852231    303                 zebrafish_non_cranial_neural_crest
# 1741687684295404    304     zebrafish_non_mesenchymal_cranial_neural_crest
# 1754382986749505    305                                      heart_tarasco
#
#                  Organism name Taxonomy ID      Marker type  \
# ID
# 1688745545837            human        9606            Genes
# 17083323392210           human        9606            Genes
# 17103172789694           human        9606  Genomic regions
# 168874554211252          human        9606            Genes
# 168874554264756          human        9606            Genes
# ...                        ...         ...              ...
# 1741686472783908     zebrafish        7955            Genes
# 1741686677329305     zebrafish        7955            Genes
# 1741687334852231     zebrafish        7955            Genes
# 1741687684295404     zebrafish        7955            Genes
# 1754382986749505     zebrafish        7955            Genes
#
#                             Submitter name  \
# ID
# 1688745545837     Kessler, Micha Frederick
# 17083323392210    Kessler, Micha Frederick
# 17103172789694    Kessler, Micha Frederick
# 168874554211252   Kessler, Micha Frederick
# 168874554264756   Kessler, Micha Frederick
# ...                                    ...
# 1741686472783908       Schultheis, Hendrik
# 1741686677329305       Schultheis, Hendrik
# 1741687334852231       Schultheis, Hendrik
# 1741687684295404       Schultheis, Hendrik
# 1754382986749505          Alayoubi, Yousef
#
#                                                       Source  \
# ID
# 1688745545837            bio-bigdata.hrbmu.edu.cn/CellMarker
# 17083323392210                                     sctoolbox
# 17103172789694                                    catlas.org
# 168874554211252                                   panglao.se
# 168874554264756                                   panglao.se
# ...                                                      ...
# 1741686472783908  https://doi.org/10.1038/s41467-021-27594-w
# 1741686677329305  https://doi.org/10.1038/s41467-021-27594-w
# 1741687334852231  https://doi.org/10.1038/s41467-021-27594-w
# 1741687684295404  https://doi.org/10.1038/s41467-021-27594-w
# 1754382986749505                               Marco Tarasco
#
#                              List type tags_transferred  \
# ID
# 1688745545837     Cell type annotation              NaN
# 17083323392210                  Gender              NaN
# 17103172789694    Cell type annotation              NaN
# 168874554211252   Cell type annotation              NaN
# 168874554264756   Cell type annotation              NaN
# ...                                ...              ...
# 1741686472783908  Cell type annotation              NaN
# 1741686677329305  Cell type annotation              NaN
# 1741687334852231  Cell type annotation              NaN
# 1741687684295404  Cell type annotation              NaN
# 1754382986749505  Cell type annotation              NaN
#
#                                                   Email                Tissue  \
# ID
# 1688745545837     Micha-Frederick.Kessler@mpi-bn.mpg.de                 fetus
# 17083323392210    Micha-Frederick.Kessler@mpi-bn.mpg.de                   NaN
# 17103172789694    Micha-Frederick.Kessler@mpi-bn.mpg.de               stomach
# 168874554211252   Micha-Frederick.Kessler@mpi-bn.mpg.de                  skin
# 168874554264756   Micha-Frederick.Kessler@mpi-bn.mpg.de                  lung
# ...                                                 ...                   ...
# 1741686472783908       hendrik.schultheis@mpi-bn.mpg.de  cranial neural crest
# 1741686677329305       hendrik.schultheis@mpi-bn.mpg.de  cranial neural crest
# 1741687334852231       hendrik.schultheis@mpi-bn.mpg.de  cranial neural crest
# 1741687684295404       hendrik.schultheis@mpi-bn.mpg.de  cranial neural crest
# 1754382986749505          yousef.alayoubi@mpi-bn.mpg.de                 heart
#
#                  Genome version        Date Life stage tags_age  \
# ID
# 1688745545837               NaN  27.03.2020        NaN      NaN
# 17083323392210              NaN         NaN        NaN      NaN
# 17103172789694             hg38         NaN        NaN      NaN
# 168874554211252             NaN  27.03.2020        NaN      NaN
# 168874554264756             NaN  27.03.2020        NaN      NaN
# ...                         ...         ...        ...      ...
# 1741686472783908            NaN         NaN     embryo  1.5 dpf
# 1741686677329305            NaN         NaN      child   14 dpf
# 1741687334852231            NaN         NaN        NaN      NaN
# 1741687684295404            NaN         NaN        NaN      NaN
# 1754382986749505            NaN         NaN        NaN      NaN
#
#                                                          tags_info  \
# ID
# 1688745545837                                                  NaN
# 17083323392210                                                 NaN
# 17103172789694                                                 NaN
# 168874554211252                                                NaN
# 168874554264756                                                NaN
# ...                                                            ...
# 1741686472783908                                               NaN
# 1741686677329305                                               NaN
# 1741687334852231                          non cranial neural crest
# 1741687684295404  non-mesenchymal cranial neural crest derivatives
# 1754382986749505                                               NaN
#
#                                                              Marker  \
# ID
# 1688745545837     [EMCN, ENSG00000164035, CD8A, ENSG00000153563,...
# 17083323392210    [EIF3MP1, ENSG00000236365, SSX1, ENSG000001267...
# 17103172789694    [CHR5:67215815-67216215, CHR21:41593222-415936...
# 168874554211252   [HLA-DRB1, ENSG00000196126, KRT1, ENSG00000167...
# 168874554264756   [SPDEF, ENSG00000124664, CFTR, ENSG00000001626...
# ...                                                             ...
# 1741686472783908  [PITX2, ENSDARG00000036194, EMX2, ENSDARG00000...
# 1741686677329305  [MYH11A, ENSDARG00000009782, CXCL12A, ENSDARG0...
# 1741687334852231  [HBBE2, ENSDARG00000045143, EPCAM, ENSDARG0000...
# 1741687684295404  [MITFA, ENSDARG00000003732, AOX5, ENSDARG00000...
# 1754382986749505  [SAMSN1A, ENSDARG00000054543, ESAMA, ENSDARG00...
#
#                                                                Info
# ID
# 1688745545837     [T cell, Pan-endothelial cell, Stromal cell, M...
# 17083323392210                                       [Gender genes]
# 17103172789694    [stomach neuroendocrine cell, CD8-positive, al...
# 168874554211252   [Sebocytes, Melanocytes, Merkel cells, Trichoc...
# 168874554264756   [Ionocytes, Alveolar macrophages, Pulmonary al...
# ...                                                             ...
# 1741686472783908  [Frontonasal, Cycling, Dorsal, Ventral, Interm...
# 1741686677329305  [Tendon/ligament, Perivascular, Hyaline cartil...
# 1741687334852231                                 [Epithelia, Blood]
# 1741687684295404  [Iridophores, Melanocytes, Otic cells, Xanthop...
# 1754382986749505  [Blood - red blood cells, Blood - Immune cells...
#
# [306 rows x 18 columns]
# Do you want to continue searching? (yes/no): no

# %% [markdown]
# Compare the lists and show the new DataFrame.

# %%
results_scored = score.compare_marker_lists(marker_df=results)
display(results_scored)
# Out:
#                            Marker                       Info  Score
# 143642         U7 ENSG00000276376               Gender genes    0.0
# 143643   RPS17P17 ENSG00000225758               Gender genes    0.0
# 143645  LINC00632 ENSG00000203930               Gender genes    0.0
# 143647   MIR320D2 ENSG00000221081               Gender genes    0.0
# 143648    SPANXB1 ENSG00000227234               Gender genes    0.0
# ...                           ...                        ...    ...
# 176698        CD4 ENSG00000010610  Proliferative CD4+ T cell    1.0
# 173767        CD4 ENSG00000010610            Effector T cell    1.0
# 173781        CD4 ENSG00000010610                 Lymphocyte    1.0
# 175936        CD4 ENSG00000010610   Memory regulatory T cell    1.0
# 190958        CD4 ENSG00000010610           Naive CD4 T cell    1.0
#
# [147379 rows x 3 columns]

# %% [markdown]
# With this function all marker scores, which are part of the <b>panglaoDB</b>, are being updated by using the calculated ubiquitousness index from the panglaoDB. The resulting DataFrame thus contains the dynamically calculated scores as well as scores of the panglaoDB - depending on whether the corresponding gene is present in the panglaoDB or not.

# %%
results_panglao = score.update_scores(repo_path=repo_path, df=results_scored)
display(results_panglao)
# Out:
#                           Marker                        Info  Score
# 60278     CHR6:11650320-11650720            endothelial cell  0.000
# 27739     CHR9:95091906-95092306     respiratory goblet cell  0.000
# 27751    CHR12:82314350-82314750     respiratory goblet cell  0.000
# 27753     CHR9:95092334-95092734     respiratory goblet cell  0.000
# 27755   CHR6:125597571-125597971     respiratory goblet cell  0.000
# ...                          ...                         ...    ...
# 174122     ITM2B ENSG00000136156  CD1C-CD141- dendritic cell  0.854
# 135852  ITM2B ENSMUSG00000022108                Müller cells  0.854
# 4936    ITM2B ENSRNOG00000016271                Müller cells  0.854
# 192407     ITM2B ENSG00000136156             Microglial cell  0.854
# 180885     ITM2B ENSG00000136156                   Astrocyte  0.854
#
# [147379 rows x 3 columns]

# %% [markdown]
# Finally the scored list can be exported.

# %%
mr.export_marker_list(results_panglao, file_name="Scored", marker_id="symbol")
# Out:
# Folder /mnt/workspace2/jdetlef/repos/annotate_by_marker_and_features/notebooks/exported_lists created.
# Marker list saved: /mnt/workspace2/jdetlef/repos/annotate_by_marker_and_features/notebooks/exported_lists/Scored
# '/mnt/workspace2/jdetlef/repos/annotate_by_marker_and_features/notebooks/exported_lists/Scored.csv'
