# %% [markdown]
# # Marker Repo - transfer markers using homology

# %% [markdown]
# In this section, with the use of homology, marker genes can be transferred from a source organism to a target organism. Two different approaches are currently available: The use of <b>BioMart and Ensemble</b> and the use of <b>HomoloGene db</b>. In the first part of this section, a wrapper function guides you through the transferring process. In the seond part the currently supported organisms of each approach are presented. Based on this, a decision can be made for one or the other approach. After that, the actual gene transfer is performed step by step.

# %% [markdown]
# ## Loading packages and autoreload

# %%
import markerrepo.marker_repo as mr
import markerrepo.homology as homol
import markerrepo.scoring as score
import markerrepo.utils as utils
import markerrepo.wrappers as wrap
import markerrepo.plotting as plot

# %load_ext autoreload
# %autoreload 2
# Out:
# /mnt/workspace2/jdetlef/.conda/envs/marker-repo/lib/python3.14/site-packages/markerrepo/wrappers.py:23: RuntimeWarning: Please install the latest sctoolbox version. Some functionality may not be available.
#   warnings.warn("Please install the latest sctoolbox version. Some functionality may not be available.", RuntimeWarning)

# %% [markdown]
# ## Settings

# %% [markdown]
# Specify path of the cloned repository.

# %%
repo_path = "/mnt/workspace2/jdetlef/repos/annotate_by_marker_and_features"

# %% [markdown]
# ## Use wrapper function and transfer genes using BioMart and HomoloGene

# %%
wrap.transfer_markers(target_org=None, source_df=None, repo_path=repo_path, target_counts=1, 
                      weight_markers=True, export_suffix="remove")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 wrap.transfer_markers(target_org=None, source_df=None, repo_path=repo_path, target_counts=1,
#       2                       weight_markers=True, export_suffix="remove")
#
# File /mnt/workspace2/jdetlef/.conda/envs/marker-repo/lib/python3.14/site-packages/markerrepo/wrappers.py:709, in transfer_markers(target_org, source_df, repo_path, lists_path, target_counts, weight_markers, export_suffix, ui, custom_file_name, ensemble, filter_transferred, verbose, suffix, biomart_target, homologene_target)
#     706 paths = []
#     707 marker_id = "ensembl" if ensemble else "symbol"
# --> 709 biomart_organisms = get_supported_biomart_organisms(repo_path=repo_path)
#     710 homologene_organisms = get_supported_taxonomy_ids(repo_path=repo_path)
#     711 supported_organisms = list(set(biomart_organisms + homologene_organisms))
#
# File /mnt/workspace2/jdetlef/.conda/envs/marker-repo/lib/python3.14/site-packages/markerrepo/homology.py:650, in get_supported_biomart_organisms(repo_path)
#     647 organisms = []
#     649 # Get organisms from Ensembl db and convert them to strings
# --> 650 dataset_list = list(create_dataset_dict().keys())
#     651 ensembl_organisms = [s.split(" genes")[0].lower() for s in dataset_list]
#     653 # Get support organisms from whitelist repository
#
# File /mnt/workspace2/jdetlef/.conda/envs/marker-repo/lib/python3.14/site-packages/markerrepo/homology.py:552, in create_dataset_dict()
#     549 _Server._check_connection = _check_connection
#     551 # Fetch available datasets from Ensembl BioMart
# --> 552 ds = find_datasets()
#     554 for _, row in ds.iterrows():
#     555     display_name = row["Dataset_name"]
#
# File /mnt/workspace2/jdetlef/.conda/envs/marker-repo/lib/python3.14/site-packages/apybiomart/apybiomart.py:34, in find_datasets(mart, save, output)
#      23 def find_datasets(mart: str = "ENSEMBL_MART_ENSEMBL",
#      24                   save: bool = False,
#      25                   output: str = "apybiomart_datasets.csv") -> pd.DataFrame:
#      26     """Retrieve and list available datasets for a given mart.
#      27
#      28     Args:
#    (...)     32             [default: 'apybiomart_datasets.csv']
#      33     """
# ---> 34     server = DatasetServer(mart, save=save, output=output)
#      35     return server.find_datasets()
#
# File /mnt/workspace2/jdetlef/.conda/envs/marker-repo/lib/python3.14/site-packages/apybiomart/classes.py:151, in DatasetServer.__init__(self, mart, save, output)
#     147 def __init__(self,
#     148              mart: str,
#     149              save: bool = False,
#     150              output: str = "apybiomart_datasets.csv"):
# --> 151     super().__init__(save=save, output=output)
#     152     self.mart = mart
#
# File /mnt/workspace2/jdetlef/.conda/envs/marker-repo/lib/python3.14/site-packages/apybiomart/classes.py:36, in _Server.__init__(self, host, save, output)
#      34 self.save = save
#      35 self.output = output
# ---> 36 if not self._check_connection():
#      37     raise _BiomartException("No internet connection available!")
#
# TypeError: create_dataset_dict.<locals>._check_connection() takes 0 positional arguments but 1 was given

# %% [markdown]
# ## Transfer markers from one organism to another using BioMart

# %% [markdown]
# ## Prepare gene transfer

# %% [markdown]
# Pull whitelist repository, update if necessary, get supported organisms, check which organisms are currently supported by BioMart or HomoloGene, choose approach, select source and target organism and finally select source markers.<br> If there are no search terms, select markers by using the guided search function.

# %%
homology_data = homol.prepare_gene_transfer(repo_path=repo_path)

# %% [markdown]
# Get the required data for the gene transfer.

# %%
biomart_db, source_df, target_genes, source_genes = homology_data

# %% [markdown]
# ### Transfer source markers to target markers using BioMart results and extend transferred markers.

# %% [markdown]
# 1. Filter source DataFrame by the number of target genes per source gene: remove all source genes that lead to more than <b>target_counts</b> target genes.

# %%
filtered_source_df = homol.transfer_markers_biomart(biomart_db, source_df, target_genes, source_whitelist=source_genes,
                                                 calc_proportions=True, plots=True, target_counts=1)

# %% [markdown]
# 2. Create DataFrame containing the transferred genes based on the filter criteria.

# %%
transferred_list = homol.transfer_markers_biomart(biomart_db, filtered_source_df, target_genes, source_whitelist=source_genes,
                                                 calc_proportions=True, plots=True, target_counts=None)
print("Transferred markers:")
display(transferred_list)

# %% [markdown]
# 3. Compare and weight markers.

# %%
results_scored = score.compare_marker_lists(marker_df=transferred_list)

# %% [markdown]
# 4. Export transferred marker list

# %%
mr.export_marker_list(results_scored, file_name="BioMart", marker_id="symbol")

# %% [markdown]
# ## Transfer markers from one organism to another using HomoloGene db

# %% [markdown]
# ## Prepare gene transfer

# %% [markdown]
# Pull whitelist repository, update if necessary, get supported organisms, check which organisms are currently supported by BioMart or HomoloGene, choose approach, select source and target organism and finally select source markers.<br> If there are no search terms, select markers by using the guided search function.

# %%
homology_data = homol.prepare_gene_transfer(repo_path=repo_path)

# %% [markdown]
# Get the required data for the gene transfer.

# %%
source_df, source_tax, target_tax, hg_db, target_genes, source_genes = homology_data

# %% [markdown]
# ### Transfer source markers to target markers using HomoloGene db and extend transferred markers.

# %% [markdown]
# 1. Filter source DataFrame by the number of target genes per source gene: remove all source genes that lead to more than <b>target_counts</b> target genes.

# %%
filtered_source_df = homol.transfer_markers_homologene(source_df, source_tax, target_tax, hg_db, target_genes,
                                           source_whitelist=source_genes, calc_proportions=True, plots=True, 
                                           target_counts=1)

# %% [markdown]
# 2. Create DataFrame containing the transferred genes based on the filter criteria.

# %%
transferred_list = homol.transfer_markers_homologene(filtered_source_df, source_tax, target_tax, hg_db, target_genes,
                                         source_whitelist=source_genes, calc_proportions=True, plots=True)
print("Transferred markers:")
display(transferred_list)

# %% [markdown]
# 3. Compare and weight markers.

# %%
results_scored = score.compare_marker_lists(marker_df=transferred_list)

# %% [markdown]
# 4. Export transferred marker list

# %%
mr.export_marker_list(results_scored, file_name="HomoloGene", marker_id="symbol")
