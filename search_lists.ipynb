# %% [markdown]
# # Marker Repo - search lists

# %% [markdown]
# ## Loading packages

# %%
import marker_repo as mr

# %% [markdown]
# ## Setting

# %%
# The path where the lists of the Marker Repo are stored - probable 'REPO_PATH/lists'
REPO_LISTS_PATH = "/mnt/workspace/mkessle/projects/annotate_by_marker_and_features/lists"

# %% [markdown]
# ## Show database

# %%
mr.getDB(REPO_LISTS_PATH)
# Out:
#   id             list_name organism_organism_name organism_taxonomy_id  \
# 0  1         Panglao_Blood                  human                 9606
# 1  2         Panglao_Heart                  mouse                10090
# 2  3           HCM_Stomach                  human                 9606
# 3  4             HCM_Brain                  human                 9606
# 4  5         Panglao_Liver                  human                 9606
# 5  6    Human_Gender_Genes                  human                 9606
# 6  7       Mouse_Cellcycle                  mouse                10090
# 7  8  Zebrafish_Mito_Genes              zebrafish                 7955
#
#   marker_type            submitter_name  \
# 0       Genes  Kessler, Micha Frederick
# 1       Genes  Kessler, Micha Frederick
# 2       Genes  Kessler, Micha Frederick
# 3       Genes            Jackson, Peter
# 4       Genes              Lynch, David
# 5       Genes  Kessler, Micha Frederick
# 6       Genes  Kessler, Micha Frederick
# 7       Genes  Kessler, Micha Frederick
#
#                          submitter_email        date  \
# 0  Micha-Frederick.Kessler@mpi-bn.mpg.de  27.03.2020
# 1  Micha-Frederick.Kessler@mpi-bn.mpg.de  27.03.2020
# 2  Micha-Frederick.Kessler@mpi-bn.mpg.de  06.01.2023
# 3                      peter@jackson.com  06.01.2023
# 4                         twin@peaks.com  08.04.1990
# 5                                    NaN         NaN
# 6                                    NaN         NaN
# 7                                    NaN         NaN
#
#                                               source tags_genotype  \
# 0                                         panglao.se            WT
# 1                                         panglao.se            WT
# 2                bio-bigdata.hrbmu.edu.cn/CellMarker            WT
# 3                bio-bigdata.hrbmu.edu.cn/CellMarker           Mut
# 4                                         panglao.se           Mut
# 5  gitlab.gwdg.de/loosolab/software/sc_framework/...            WT
# 6  gitlab.gwdg.de/loosolab/software/sc_framework/...            WT
# 7  gitlab.gwdg.de/loosolab/software/sc_framework/...            WT
#
#   tags_gender tags_life_stage                                tags_injury  \
# 0       mixed           adult                 injury_status: non-injured
# 1        male     young adult                 injury_status: non-injured
# 2       mixed           adult                 injury_status: non-injured
# 3      female          embryo  injury_status: injured\ninjury_type: sham
# 4       mixed           elder                                        NaN
# 5       mixed             NaN                                        NaN
# 6         NaN             NaN                                        NaN
# 7       mixed             NaN                                        NaN
#
#   tags_tissue                 tags_treatment
# 0         NaN                            NaN
# 1       heart                            NaN
# 2     stomach                            NaN
# 3       brain                            NaN
# 4       liver  treatment_status: not treated
# 5         NaN                            NaN
# 6         NaN                            NaN
# 7         NaN                            NaN
