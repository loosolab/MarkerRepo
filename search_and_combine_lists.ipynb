# %% [markdown]
# # Marker Repo - search and combine lists

# %% [markdown]
# ## Loading packages

# %%
import marker_repo as mr

# %% [markdown]
# ## Setting

# %%
# The path where the lists of the Marker Repo are stored - probable 'REPO_PATH/lists'
REPO_LISTS_PATH = "/mnt/workspace/mkessle/projects/annotate_by_marker_and_features/lists"

# %% [markdown]
# ## Get and show database

# %%
db = mr.get_db(REPO_LISTS_PATH)
display(db)
# Out:
#                list_name organism_organism_name organism_taxonomy_id  \
# id
# 1          Panglao_Blood                  human                 9606
# 2          Panglao_Heart                  mouse                10090
# 3            HCM_Stomach                  human                 9606
# 4              HCM_Brain                  human                 9606
# 5          Panglao_Liver                  human                 9606
# 6     Human_Gender_Genes                  human                 9606
# 7        Mouse_Cellcycle                  mouse                10090
# 8   Zebrafish_Mito_Genes              zebrafish                 7955
# 9    Zebrafish_Cellcycle              zebrafish                 7955
#
#    marker_type            submitter_name  \
# id
# 1        Genes  Kessler, Micha Frederick
# 2        Genes  Kessler, Micha Frederick
# 3        Genes  Kessler, Micha Frederick
# 4        Genes            Jackson, Peter
# 5        Genes              Lynch, David
# 6        Genes  Kessler, Micha Frederick
# 7        Genes  Kessler, Micha Frederick
# 8        Genes  Kessler, Micha Frederick
# 9        Genes  Kessler, Micha Frederick
#
#                           submitter_email        date  \
# id
# 1   Micha-Frederick.Kessler@mpi-bn.mpg.de  27.03.2020
# 2   Micha-Frederick.Kessler@mpi-bn.mpg.de  27.03.2020
# 3   Micha-Frederick.Kessler@mpi-bn.mpg.de  06.01.2023
# 4                       peter@jackson.com  06.01.2023
# 5                          twin@peaks.com  08.04.1990
# 6                                     NaN         NaN
# 7                                     NaN         NaN
# 8                                     NaN         NaN
# 9                                     NaN         NaN
#
#                                                source tags_genotype  \
# id
# 1                                          panglao.se            WT
# 2                                          panglao.se            WT
# 3                 bio-bigdata.hrbmu.edu.cn/CellMarker            WT
# 4                 bio-bigdata.hrbmu.edu.cn/CellMarker           Mut
# 5                                          panglao.se           Mut
# 6   gitlab.gwdg.de/loosolab/software/sc_framework/...            WT
# 7   gitlab.gwdg.de/loosolab/software/sc_framework/...            WT
# 8   gitlab.gwdg.de/loosolab/software/sc_framework/...            WT
# 9                                                 NaN           NaN
#
#    tags_gender tags_life_stage                                tags_injury  \
# id
# 1        mixed           adult                 injury_status: non-injured
# 2         male     young adult                 injury_status: non-injured
# 3        mixed           adult                 injury_status: non-injured
# 4       female          embryo  injury_status: injured\ninjury_type: sham
# 5        mixed           elder                                        NaN
# 6        mixed             NaN                                        NaN
# 7          NaN             NaN                                        NaN
# 8        mixed             NaN                                        NaN
# 9          NaN             NaN                                        NaN
#
#    tags_tissue                 tags_treatment
# id
# 1          NaN                            NaN
# 2        heart                            NaN
# 3      stomach                            NaN
# 4        brain                            NaN
# 5        liver  treatment_status: not treated
# 6          NaN                            NaN
# 7          NaN                            NaN
# 8          NaN                            NaN
# 9          NaN                            NaN

# %% [markdown]
# ## Search database

# %% [markdown]
# Enter dictionary with key: column and value: keyword or enter a string to search the whole database:<br>
# keywords = {"list_name": "Heart"} -> take only the column "list_name" into account<br>
# keywords = {"submitter_name": "Kessler", "tags_gender": "mixed"}  -> take only the columns "submitter_name" and "gender" into account<br>
# keywords = "WT" -> take all columns into account<br>

# %% [markdown]
# ### Examples

# %%
keywords = {"list_name": "Heart"}
mr.search_db(db, keywords, case_sensitive=False, exact=False)
# Out:
#         list_name organism_organism_name organism_taxonomy_id marker_type  \
# id
# 2   panglao_heart                  mouse                10090       genes
#
#               submitter_name                        submitter_email  \
# id
# 2   kessler, micha frederick  micha-frederick.kessler@mpi-bn.mpg.de
#
#           date      source tags_genotype tags_gender tags_life_stage  \
# id
# 2   27.03.2020  panglao.se            wt        male     young adult
#
#                    tags_injury tags_tissue tags_treatment
# id
# 2   injury_status: non-injured       heart            NaN

# %%
keywords = {"submitter_name": "Kessler", "tags_gender": "mixed"} 
mr.search_db(db, keywords, case_sensitive=True, exact=False)
# Out:
#                list_name organism_organism_name organism_taxonomy_id  \
# id
# 1          Panglao_Blood                  human                 9606
# 3            HCM_Stomach                  human                 9606
# 6     Human_Gender_Genes                  human                 9606
# 8   Zebrafish_Mito_Genes              zebrafish                 7955
#
#    marker_type            submitter_name  \
# id
# 1        Genes  Kessler, Micha Frederick
# 3        Genes  Kessler, Micha Frederick
# 6        Genes  Kessler, Micha Frederick
# 8        Genes  Kessler, Micha Frederick
#
#                           submitter_email        date  \
# id
# 1   Micha-Frederick.Kessler@mpi-bn.mpg.de  27.03.2020
# 3   Micha-Frederick.Kessler@mpi-bn.mpg.de  06.01.2023
# 6                                     NaN         NaN
# 8                                     NaN         NaN
#
#                                                source tags_genotype  \
# id
# 1                                          panglao.se            WT
# 3                 bio-bigdata.hrbmu.edu.cn/CellMarker            WT
# 6   gitlab.gwdg.de/loosolab/software/sc_framework/...            WT
# 8   gitlab.gwdg.de/loosolab/software/sc_framework/...            WT
#
#    tags_gender tags_life_stage                 tags_injury tags_tissue  \
# id
# 1        mixed           adult  injury_status: non-injured         NaN
# 3        mixed           adult  injury_status: non-injured     stomach
# 6        mixed             NaN                         NaN         NaN
# 8        mixed             NaN                         NaN         NaN
#
#    tags_treatment
# id
# 1             NaN
# 3             NaN
# 6             NaN
# 8             NaN

# %%
keywords = "WT"
mr.search_db(db, keywords, case_sensitive=True, exact=True)
# Out:
#                list_name organism_organism_name organism_taxonomy_id  \
# id
# 1          Panglao_Blood                  human                 9606
# 2          Panglao_Heart                  mouse                10090
# 3            HCM_Stomach                  human                 9606
# 6     Human_Gender_Genes                  human                 9606
# 7        Mouse_Cellcycle                  mouse                10090
# 8   Zebrafish_Mito_Genes              zebrafish                 7955
#
#    marker_type            submitter_name  \
# id
# 1        Genes  Kessler, Micha Frederick
# 2        Genes  Kessler, Micha Frederick
# 3        Genes  Kessler, Micha Frederick
# 6        Genes  Kessler, Micha Frederick
# 7        Genes  Kessler, Micha Frederick
# 8        Genes  Kessler, Micha Frederick
#
#                           submitter_email        date  \
# id
# 1   Micha-Frederick.Kessler@mpi-bn.mpg.de  27.03.2020
# 2   Micha-Frederick.Kessler@mpi-bn.mpg.de  27.03.2020
# 3   Micha-Frederick.Kessler@mpi-bn.mpg.de  06.01.2023
# 6                                     NaN         NaN
# 7                                     NaN         NaN
# 8                                     NaN         NaN
#
#                                                source tags_genotype  \
# id
# 1                                          panglao.se            WT
# 2                                          panglao.se            WT
# 3                 bio-bigdata.hrbmu.edu.cn/CellMarker            WT
# 6   gitlab.gwdg.de/loosolab/software/sc_framework/...            WT
# 7   gitlab.gwdg.de/loosolab/software/sc_framework/...            WT
# 8   gitlab.gwdg.de/loosolab/software/sc_framework/...            WT
#
#    tags_gender tags_life_stage                 tags_injury tags_tissue  \
# id
# 1        mixed           adult  injury_status: non-injured         NaN
# 2         male     young adult  injury_status: non-injured       heart
# 3        mixed           adult  injury_status: non-injured     stomach
# 6        mixed             NaN                         NaN         NaN
# 7          NaN             NaN                         NaN         NaN
# 8        mixed             NaN                         NaN         NaN
#
#    tags_treatment
# id
# 1             NaN
# 2             NaN
# 3             NaN
# 6             NaN
# 7             NaN
# 8             NaN

# %% [markdown]
# ## Combine lists

# %% [markdown]
# Example 1: Combine all lists which contain the keyword "mixed".

# %%
# Save search results in "df"
keywords = "Genes"
df = mr.search_db(db, keywords, case_sensitive=False, exact=True)

# Get UIDs and combine lists
uids = [int(idx) for idx in df.index]
combined_df = mr.combine_lists(REPO_LISTS_PATH, uids)
display(combined_df)

# Drop duplicates (redundant if you want to submit the new list using the submit_lists notebook)
markers_filtered = combined_df.drop_duplicates()
display(markers_filtered)

# Export marker list
mr.export_marker_list(REPO_LISTS_PATH, "Mixed", combined_df)
# Out:
#                              Marker           Info
# 0               CGA ENSG00000135346  Erythroblasts
# 1              TFRC ENSG00000072274  Erythroblasts
# 2              CDH1 ENSG00000039068  Erythroblasts
# 3               WRN ENSG00000165392  Erythroblasts
# 4              CD44 ENSG00000026508  Erythroblasts
# ...                             ...            ...
# 5967       NDC80 ENSDARG00000071694      g2m_genes
# 5968       CCNB2 ENSDARG00000036180      g2m_genes
# 5969  ZGC:153426 ENSDARG00000104436      g2m_genes
# 5970       KIF23 ENSDARG00000014943      g2m_genes
# 5971        CTCF ENSDARG00000056621      g2m_genes
#
# [5972 rows x 2 columns]
#                              Marker           Info
# 0               CGA ENSG00000135346  Erythroblasts
# 1              TFRC ENSG00000072274  Erythroblasts
# 2              CDH1 ENSG00000039068  Erythroblasts
# 3               WRN ENSG00000165392  Erythroblasts
# 4              CD44 ENSG00000026508  Erythroblasts
# ...                             ...            ...
# 5967       NDC80 ENSDARG00000071694      g2m_genes
# 5968       CCNB2 ENSDARG00000036180      g2m_genes
# 5969  ZGC:153426 ENSDARG00000104436      g2m_genes
# 5970       KIF23 ENSDARG00000014943      g2m_genes
# 5971        CTCF ENSDARG00000056621      g2m_genes
#
# [5965 rows x 2 columns]
# Combined list saved: /mnt/workspace/mkessle/projects/annotate_by_marker_and_features/lists/Mixed
